# %% [markdown]
# <a href="https://colab.research.google.com/github/devil0913563/nuralnetwrok/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.preprocessing import normalize

# %%
data=pd.read_csv("/content/Iris.csv")
print("Describing the data: ",data.describe())
print("Info of the data:",data.info())
# Out:
# Describing the data:                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
# ...

# %%
print("60 first samples of the dataset:",data.head(10))
print("60 last samples of the dataset:",data.tail(10))
# Out:
# 60 first samples of the dataset:    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa
# ...

# %%
sns.lmplot(x='SepalLengthCm', y='SepalWidthCm',
           data=data,
           fit_reg=False,
           hue="Species",
           scatter_kws={"marker": "D",
                        "s": 45})
plt.title('SepalLength vs SepalWidth')

sns.lmplot(x='PetalLengthCm', y='PetalWidthCm',
           data=data,
           fit_reg=False,
           hue="Species",
           scatter_kws={"marker": "D",
                        "s": 45})
plt.title('PetalLength vs PetalWidth')

sns.lmplot(x='SepalLengthCm', y='PetalLengthCm',
           data=data,
           fit_reg=False,
           hue="Species",
           scatter_kws={"marker": "D",
                        "s": 45})
plt.title('SepalLength vs PetalLength')

sns.lmplot(x='SepalWidthCm', y='PetalWidthCm',
           data=data,
           fit_reg=False,
           hue="Species",
           scatter_kws={"marker": "D",
                        "s": 45})
plt.title('SepalWidth vs PetalWidth')
plt.show()

# %%
X=data.iloc[:,1:4].values
y=data.iloc[:,4].values

print("Shape of X",X.shape)
print("Shape of y",y.shape)
print("Examples of X\n",X[:4])
print("Examples of y\n",y[:4])
# Out:
# Shape of X (150, 3)
# Shape of y (150,)
# Examples of X
#  [[5.1 3.5 1.4]
#  [4.9 3.  1.4]
#  [4.7 3.2 1.3]
#  [4.6 3.1 1.5]]
# Examples of y
#  [0.2 0.2 0.2 0.2]

# %%
X_normalized=normalize(X,axis=0)
print("Examples of X_normalised\n",X_normalized[:4])
# Out:
# Examples of X_normalised
#  [[0.07056264 0.09265065 0.02754646]
#  [0.06779548 0.07941484 0.02754646]
#  [0.06502832 0.08470916 0.02557886]
#  [0.06364474 0.082062   0.02951407]]

# %%
total_length=len(data)
train_length=int(0.85*total_length)
test_length=int(0.15*total_length)

X_train=X_normalized[:train_length]
X_test=X_normalized[train_length:]
y_train=y[:train_length]
y_test=y[train_length:]

print("Length of train set x:",X_train.shape[0],"y:",y_train.shape[0])
print("Length of test set x:",X_test.shape[0],"y:",y_test.shape[0])
# Out:
# Length of train set x: 127 y: 127
# Length of test set x: 23 y: 23
